# %% [markdown]
# Q--What is Python, and why is it popular
#
# A—python is a programming language with easy syntax and can be easily
# compiled. It is popular because iy=t can be learned easily and it is
# widely used in the field of modern technology like machine learning ,AI
# ,web development etc….
#
# Q--What is an interpreter in Python
#
# A—In Python, an **interpreter** is a program that reads and executes the
# code written in Python.
#
# Q--What are pre-defined keywords in Python
#
# A—Pre defined keywords in python are the pre decided words which already
# have some specific function and cannot be used by any user as it already
# have some specific task or work to perform.
#
# Q--Can keywords be used as variable names
#
# A—No key words cannot be used as a variable name , as they already store
# some specific data..
#
# Q--What is mutability in Python
#
# A—Mutabilty in python is defined as if the datatype can be modified or
# can be edited after execution
#
# Q--Why are lists mutable, but tuples are immutable
#
# A—Lists are mutable in python because lists can be edited or cam be
# modified whereas tuples cannot be modified or be edited ..
#
# Q--What is the difference between “==” and “is” operators in Python
#
# A--The == operator checks if the **values** of two objects are equal.
#
# The is operator checks if two objects are the **same object in memory**
#
# Q--What are logical operators in Python
#
# A—Python, logical operators are used to combine conditional statements
# and return a Boolean value.
#
# Primarly there are basically 3 main logoca operators in python and they
# are ….AND,OR,NOT.
#
# Q--What is type casting in Python
#
# A—type casting in python ca be defined as the process by which we can
# change or modify an value from one data type to another data type as per
# the requirement.
#
# Q--What is the difference between implicit and explicit type casting
#
# A—Implicit type casting can be defoned the type of data conversion in
# which the data gets converted into a particular data type by its own
# whereas explicit type casting a in python is the type of data conversion
# in which the user needs to give instruction for the data conversion.
#
# Q--What is the purpose of conditional statements in Python
#
# A—the main purpose of conditional statements in python is to detect a
# specific condition or task from a multiple task as per the desired
# requirement
#
# Q--How does the elif statement work
#
# A--The elif statement in Python is short for "else if" and is used as
# part of a conditional structure to check multiple conditions.
#
# Q--What is the difference between for and while loops
#
# A--A for loop iterates over a sequence or range for a known number of
# times, while a while loop repeats as long as a condition remains True.
#
# Q--Describe a scenario where a while loop is more suitable than a for
# loop.
#
# A—while loop can be suitable than for loop when we ae not sure about the
# range.
